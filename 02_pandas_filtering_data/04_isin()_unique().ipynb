# %%
import pandas as pd

# %%
df_laptops = pd.read_csv('laptop_price.csv')

# %%
df_laptops.head(3)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
#
#                      ScreenResolution                         Cpu  Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz  8GB
# 1                            1440x900        Intel Core i5 1.8GHz  8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz  8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00

# %% [markdown]
# ## .isin()

# %% [markdown]
# ### Single Filtering

# %%
# select Apple or HP Laptops
filter1 = df_laptops['Company'].isin(['Apple', 'HP'])
filter1
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1251     True
# 1252    False
# 1253    False
# 1254    False
# 1255    False
# Name: Company, Length: 1256, dtype: bool

# %%
# filter dataframes
df_laptops[filter1]
# Out:
#       laptop_ID Company                                Product   TypeName  \
# 0             1   Apple                            MacBook Pro  Ultrabook
# 1             2   Apple                            Macbook Air  Ultrabook
# 2             3      HP                                 250 G6   Notebook
# 3             4   Apple                            MacBook Pro  Ultrabook
# 4             5   Apple                            MacBook Pro  Ultrabook
# ...         ...     ...                                    ...        ...
# 1234       1252   Apple                            MacBook Air  Ultrabook
# 1235       1253      HP  15-bs023nv (i3-6006U/4GB/1TB/FHD/W10)   Notebook
# 1236       1254      HP                          EliteBook 840  Ultrabook
# 1244       1262      HP                          EliteBook 840   Notebook
# 1251       1269      HP                                 255 G6   Notebook
#
#       Inches                    ScreenResolution                         Cpu  \
# 0       13.3  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz
# 1       13.3                            1440x900        Intel Core i5 1.8GHz
# 2       15.6                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz
# 3       15.4  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz
# 4       13.3  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz
# ...      ...                                 ...                         ...
# 1234    11.6                            1366x768        Intel Core i5 1.6GHz
# 1235    15.6                   Full HD 1920x1080    Intel Core i3 6006U 2GHz
# 1236    14.0                           2560x1440  Intel Core i7 6500U 2.5GHz
# 1244    14.0                   Full HD 1920x1080  Intel Core i5 6200U 2.3GHz
# 1251    15.6                            1366x768   AMD A6-Series 9220 2.5GHz
#
#        Ram               Memory                           Gpu       OpSys  \
# 0      8GB            128GB SSD  Intel Iris Plus Graphics 640       macOS
# 1      8GB  128GB Flash Storage        Intel HD Graphics 6000       macOS
# 2      8GB            256GB SSD         Intel HD Graphics 620       No OS
# 3     16GB            512GB SSD            AMD Radeon Pro 455       macOS
# 4      8GB            256GB SSD  Intel Iris Plus Graphics 650       macOS
# ...    ...                  ...                           ...         ...
# 1234   4GB  256GB Flash Storage        Intel HD Graphics 6000    Mac OS X
# 1235   4GB              1TB HDD         Intel HD Graphics 520  Windows 10
# 1236   8GB            256GB SSD         Intel HD Graphics 520   Windows 7
# 1244   4GB            256GB SSD         Intel HD Graphics 520   Windows 7
# 1251   4GB            500GB HDD        AMD Radeon R4 Graphics  Windows 10
#
#       Weight  Price_euros
# 0     1.37kg      1339.69
# 1     1.34kg       898.94
# 2     1.86kg       575.00
# 3     1.83kg      2537.45
# 4     1.37kg      1803.60
# ...      ...          ...
# 1234  1.08kg       959.00
# 1235   2.1kg       478.00
# 1236  1.54kg      2198.19
# 1244  1.54kg      1099.99
# 1251  1.86kg       399.00
#
# [286 rows x 13 columns]

# %% [markdown]
# ### Multiple Filtering

# %%
# find notebooks or ultabooks from Apple or HP
filter2 = df_laptops['TypeName'].isin(['Notebook', 'Ultrabook'])

# %%
# filter dataframe
df_laptops[filter1 & filter2]
# Out:
#       laptop_ID Company                                Product   TypeName  \
# 0             1   Apple                            MacBook Pro  Ultrabook
# 1             2   Apple                            Macbook Air  Ultrabook
# 2             3      HP                                 250 G6   Notebook
# 3             4   Apple                            MacBook Pro  Ultrabook
# 4             5   Apple                            MacBook Pro  Ultrabook
# ...         ...     ...                                    ...        ...
# 1234       1252   Apple                            MacBook Air  Ultrabook
# 1235       1253      HP  15-bs023nv (i3-6006U/4GB/1TB/FHD/W10)   Notebook
# 1236       1254      HP                          EliteBook 840  Ultrabook
# 1244       1262      HP                          EliteBook 840   Notebook
# 1251       1269      HP                                 255 G6   Notebook
#
#       Inches                    ScreenResolution                         Cpu  \
# 0       13.3  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz
# 1       13.3                            1440x900        Intel Core i5 1.8GHz
# 2       15.6                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz
# 3       15.4  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz
# 4       13.3  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz
# ...      ...                                 ...                         ...
# 1234    11.6                            1366x768        Intel Core i5 1.6GHz
# 1235    15.6                   Full HD 1920x1080    Intel Core i3 6006U 2GHz
# 1236    14.0                           2560x1440  Intel Core i7 6500U 2.5GHz
# 1244    14.0                   Full HD 1920x1080  Intel Core i5 6200U 2.3GHz
# 1251    15.6                            1366x768   AMD A6-Series 9220 2.5GHz
#
#        Ram               Memory                           Gpu       OpSys  \
# 0      8GB            128GB SSD  Intel Iris Plus Graphics 640       macOS
# 1      8GB  128GB Flash Storage        Intel HD Graphics 6000       macOS
# 2      8GB            256GB SSD         Intel HD Graphics 620       No OS
# 3     16GB            512GB SSD            AMD Radeon Pro 455       macOS
# 4      8GB            256GB SSD  Intel Iris Plus Graphics 650       macOS
# ...    ...                  ...                           ...         ...
# 1234   4GB  256GB Flash Storage        Intel HD Graphics 6000    Mac OS X
# 1235   4GB              1TB HDD         Intel HD Graphics 520  Windows 10
# 1236   8GB            256GB SSD         Intel HD Graphics 520   Windows 7
# 1244   4GB            256GB SSD         Intel HD Graphics 520   Windows 7
# 1251   4GB            500GB HDD        AMD Radeon R4 Graphics  Windows 10
#
#       Weight  Price_euros
# 0     1.37kg      1339.69
# 1     1.34kg       898.94
# 2     1.86kg       575.00
# 3     1.83kg      2537.45
# 4     1.37kg      1803.60
# ...      ...          ...
# 1234  1.08kg       959.00
# 1235   2.1kg       478.00
# 1236  1.54kg      2198.19
# 1244  1.54kg      1099.99
# 1251  1.86kg       399.00
#
# [235 rows x 13 columns]

# %% [markdown]
# ## unique()

# %% [markdown]
# Return unique values of a Series object in order of appearance.

# %%
# get unique elements in the "Company" column
check_uniques = df_laptops['Company'].unique()
check_uniques
# Out:
# array(['Apple', 'HP', 'Acer', 'Asus', 'Dell', 'Lenovo', 'Chuwi', 'MSI',
#        'Microsoft', 'Toshiba', 'Huawei', 'Xiaomi', 'Vero', 'Razer',
#        'Mediacom', 'Samsung', 'Google', 'Fujitsu', 'LG'], dtype=object)

# %%
# get the length of unique elements array
len(check_uniques)
# Out:
# 19

# %% [markdown]
# ## nunique()

# %% [markdown]
# Return the number of unique elements in a Series object, excluding NA values.

# %%
count_uniques = df_laptops['Company'].nunique()
count_uniques
# Out:
# 19
