# %%
import pandas as pd
import numpy as np

# %%
# reading the csv file
df_exams = pd.read_csv('StudentsPerformance.csv')
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# ## Select One Column from a Data Frame

# %% [markdown]
# ### Option One

# %%
# preferred way to select a column with []
col1 = df_exams['gender']

# %%
# check type, index and head
type(col1)
# Out:
# pandas.core.series.Series

# %%
col1.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
col1.head()
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object

# %% [markdown]
# ### Option Two

# %%
# not recommended way to select a column with a .
col2 = df_exams.gender
col2.head()
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object

# %%
# fails if there is a space in the column's name
# col2 = df_exams.math score

# %%
# select a column with a space in its name the proper way
col2 = df_exams['math score']
col2.head()
# Out:
# 0    72
# 1    69
# 2    90
# 3    47
# 4    76
# Name: math score, dtype: int64

# %% [markdown]
# ## Select Two or More Columns from a Data Frame

# %%
# select more than one column
cols = df_exams[['gender', 'math score', 'lunch']]
cols.head()
# Out:
#    gender  math score         lunch
# 0  female          72      standard
# 1  female          69      standard
# 2  female          90      standard
# 3    male          47  free/reduced
# 4    male          76      standard

# %%
# checking type of the selection
type(cols)
# Out:
# pandas.core.frame.DataFrame

# %%
# selecting more than one column is not possible with .

# %% [markdown]
# ## Add a new Column to the Data Frame

# %% [markdown]
# ### Add a new Column with a Scalar Value

# %%
df_exams['language score'] = 70
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    language score
# 0              70
# 1              70
# 2              70
# 3              70
# 4              70

# %% [markdown]
# ### Add a new Column with an Array

# %%
# create an array with 1000 elements
language_score = np.arange(0,1000)

# %%
# check its length
len(language_score)
# Out:
# 1000

# %%
# add a new column to the Data Frame with an Array
df_exams['language score'] = language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                 0
# 1                 1
# 2                 2
# 3                 3
# 4                 4
# ..              ...
# 995             995
# 996             996
# 997             997
# 998             998
# 999             999
#
# [1000 rows x 9 columns]

# %%
# create a random integer number array from 1 to 100
int_language_score = np.random.randint(1, 100, size=1000)

# %%
# check min/max e;ements
print(min(int_language_score))
print(max(int_language_score))
# Out:
# 1
# 99

# %%
# add a new column to the Data Frame with an Array
df_exams['language score'] = int_language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                35
# 1                90
# 2                20
# 3                71
# 4                68
# ..              ...
# 995              95
# 996              30
# 997              55
# 998              59
# 999              73
#
# [1000 rows x 9 columns]

# %%
# create a random float numbers between 1 and 10
np.random.uniform(1, 10, size=10)
# Out:
# array([3.74997732, 5.78856075, 7.3490708 , 6.60196432, 1.9198916 ,
#        7.26575942, 4.95784058, 7.04535079, 6.96545996, 5.14647815])

# %% [markdown]
# ### Add a new Column with assign()

# %% [markdown]
# WHen to use assign?
#
#     - Add multiple columns in a single line of code.
#     - Overwrite the values of an existing columns (best practice).
#
# It returns a new object(a copy) with all the original columns in addition to the new ones.

# %%
# create two arrays with random numbers to be inserted as columns in the Data Frame
score1 = np.random.randint(1,100, size=1000)
score2 = np.random.randint(1,100, size=1000)

# %%
# create Series from the arrays
series1 = pd.Series(score1, index=np.arange(0,1000))
series2 = pd.Series(score2, index=np.arange(0,1000))

# %%
df_exams = df_exams.assign(reliability=series1, procrastination=series2)
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  reliability  procrastination
# 0                35           95               11
# 1                90           59               43
# 2                20           17               52
# 3                71           85               58
# 4                68           32               41
# ..              ...          ...              ...
# 995              95           67               82
# 996              30           90               83
# 997              55           56               14
# 998              59           11               18
# 999              73            8               35
#
# [1000 rows x 11 columns]

# %% [markdown]
# ### Add a new Column with insert()

# %% [markdown]
# Inserts a new column at a specific position/index.

# %%
# add a new column at a specific position with insert to the Data Frame
df_exams.insert(1, 'insert at index 1', series1)
df_exams
# Out:
#      gender  insert at index 1 race/ethnicity parental level of education  \
# 0    female                 95        group B           bachelor's degree
# 1    female                 59        group C                some college
# 2    female                 17        group B             master's degree
# 3      male                 85        group A          associate's degree
# 4      male                 32        group C                some college
# ..      ...                ...            ...                         ...
# 995  female                 67        group E             master's degree
# 996    male                 90        group C                 high school
# 997  female                 56        group C                 high school
# 998  female                 11        group D                some college
# 999  female                  8        group D                some college
#
#             lunch test preparation course  math score  reading score  \
# 0        standard                    none          72             72
# 1        standard               completed          69             90
# 2        standard                    none          90             95
# 3    free/reduced                    none          47             57
# 4        standard                    none          76             78
# ..            ...                     ...         ...            ...
# 995      standard               completed          88             99
# 996  free/reduced                    none          62             55
# 997  free/reduced               completed          59             71
# 998      standard               completed          68             78
# 999  free/reduced                    none          77             86
#
#      writing score  language score  reliability  procrastination
# 0               74              35           95               11
# 1               88              90           59               43
# 2               93              20           17               52
# 3               44              71           85               58
# 4               75              68           32               41
# ..             ...             ...          ...              ...
# 995             95              95           67               82
# 996             55              30           90               83
# 997             65              55           56               14
# 998             77              59           11               18
# 999             86              73            8               35
#
# [1000 rows x 12 columns]
